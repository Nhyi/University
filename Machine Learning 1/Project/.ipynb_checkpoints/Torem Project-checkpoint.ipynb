# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ### Data Exploration

# %%
#read the data in as pandas df...
df = pd.read_csv('maize_major_yield.csv')
df_copy = df.copy()

# %% [markdown]
# #### Statistics of target variable - yield

# %%
target = df_copy['yield']

mean = round(target.mean(),2)
std = round(target.std(),2)
maximum = round(target.max(),2)
minimum = round(target.min(),2)

print(f'Yield mean: {mean}')
print(f'Yield standard deviation: {std}')
print(f'Yield maximum: {maximum}')
print(f'Yield minimum: {minimum}')
# Out:
# Yield mean: 3.62
# Yield standard deviation: 3.67
# Yield maximum: 31.16
# Yield minimum: 0.0

# %% [markdown]
# ## Data Visualisation
#
# ### Visualising yield against time

# %%
years = df_copy['year'].to_numpy()
unique_years = np.unique(years)

dic = dict()

#Collect all yields for each year...

for year in unique_years:
    yields = df_copy.loc[df_copy['year'] == year, 'yield']
    mean = yields.mean()
    dic[year] = mean
    
lists = sorted(dic.items()) # return a list of tuples
x, y = zip(*lists)

plt.figure(figsize=[10,8])
plt.grid(True)
plt.title('Average yield against Time')
plt.xlabel('Year')
plt.ylabel('Average yield (tonnes per hectare)')
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Visualising Yield against Rainfall - 1983 & 2013
#
# ##### Assuming that rainfall is measured in mm

# %%
def wanted_variable(year, variable, mean = False):
    '''Function that looks at a particular year and selects the columns for a particular exemplar
    the criteria used to select the columns is the variable parameter
    If the mean parameter is set to True then calculate the mean of the selected columns'''
    
    wanted_year = df_copy.loc[df_copy['year'] == year]
    wanted_columns = wanted_year[wanted_year.columns[wanted_year.columns.to_series().str.contains(variable)]]
    yields = wanted_year['yield']
    
    if mean == True:
        average = wanted_columns.mean(axis=1)
        return average, yields
    else:
        return wanted_columns, yields
        
#the year 1983...
plt.figure(figsize=[10,8])
plt.grid(True)
plt.title('Average rainfall against yield - 1983')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (tonnes per hectare)')
plt.scatter(wanted_variable(1983, 'rain', True)[0], wanted_variable(1983, 'rain', True)[1])
plt.show()

#the year 2013...
plt.figure(figsize=[10,8])
plt.grid(True)
plt.title('Average rainfall against yield - 2013')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (tonnes per hectare)')
plt.scatter(wanted_variable(2013, 'rain', True)[0], wanted_variable(2013, 'rain', True)[1])
plt.show()
# Out:
# 0        27.233333
# 1        17.583333
# 2        97.808333
# 3       137.450000
# 4        34.916667
#            ...
# 1019    148.883333
# 1020     59.208333
# 1021     46.833333
# 1022     76.250000
# 1023    203.083333
# Length: 1024, dtype: float64

# %% [markdown]
# #### Less concentration around the origin, crops are able to produce higher yields at higher and lower levels of rainfall

# %%
#find the coldest and warmest months on average...

mini = wanted_variable(1983, ' mean min temperature')[0].mean(axis=0)
maxi = wanted_variable(1983, ' mean max temperature')[0].mean(axis=0)

#coldest month is december
print(mini)
print(mini.min())

#warmest month is july
print(maxi)
print(maxi.max())
# Out:
# jan mean min temperature     8.422852
# feb mean min temperature     9.453613
# mar mean min temperature    11.800879
# apr mean min temperature    13.645801
# may mean min temperature    15.137207
# jun mean min temperature    16.024316
# jul mean min temperature    17.091992
# aug mean min temperature    17.065039
# sep mean min temperature    15.758984
# oct mean min temperature    13.697656
# nov mean min temperature    11.518750
# dec mean min temperature     8.353125
# dtype: float64
# 8.353124999999988
# jan mean max temperature    18.223633
# feb mean max temperature    19.787207
# mar mean max temperature    22.168555
# apr mean max temperature    24.308789
# may mean max temperature    26.109180
# jun mean max temperature    26.945898
# jul mean max temperature    27.942187
# aug mean max temperature    27.904199
# sep mean max temperature    27.239746
# oct mean max temperature    24.817676
# nov mean max temperature    22.283496
# dec mean max temperature    18.316602
# dtype: float64
# 27.942187499999925

# %%
plt.figure(figsize=[10,8])
plt.grid(True)
plt.title('Mean Min Temperature against yield - 1983 December')
plt.xlabel('Temperature')
plt.ylabel('Yield (tonnes per hectare)')
plt.scatter(wanted_variable(1983, 'dec mean min temperature')[0], wanted_variable(1983, 'dec mean min temperature', True)[1])
plt.show()

plt.figure(figsize=[10,8])
plt.grid(True)
plt.title('Mean Max Temperature against yield - 1983 July')
plt.xlabel('Temperature')
plt.ylabel('Yield (tonnes per hectare)')
plt.scatter(wanted_variable(1983, 'jul mean max temperature')[0], wanted_variable(1983, 'jul mean max temperature', True)[1])
plt.show()

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Normalisation of the Data

# %%
# Normalising the data

#convert into numpy array...
df_np = df_copy.to_numpy()

#go through all elements in the list, effectively each column - not the year
for i in range(len(df_np[0])):
    #don't normalise the first column as it is a discrete time variable
    if i == 0:
        pass
    else:
        #calculate the mean and standard deviation...
        std = np.std(df_np[:,i])
        mean = np.mean(df_np[:,i])
        
        #substract the mean and divide by the standard deviation...
        df_np[:,i] = (df_np[:,i] - mean)/std

# %%
df = pd.DataFrame(df_np)
df.columns = df_copy.columns.values
df
# Out:
#          year  jan rain  jan mean min temperature  jan mean max temperature  \
# 0      1983.0 -0.652345                 -1.337996                 -1.195415
# 1      1983.0 -0.676903                  1.078321                  0.950843
# 2      1983.0 -0.676903                  0.900764                  1.069257
# 3      1983.0  1.661027                  1.032002                  0.869433
# 4      1983.0  0.403653                  0.900764                  1.150667
# ...       ...       ...                       ...                       ...
# 31739  2013.0  0.231746                  0.777246                  0.921239
# 31740  2013.0 -0.541833                 -0.403893                 -0.751362
# 31741  2013.0 -0.518094                 -0.982882                 -0.632947
# 31742  2013.0 -0.199657                  0.769526                  0.995248
# 31743  2013.0 -0.368290                  0.561090                  0.899037
#
#        feb rain  feb mean min temperature  feb mean max temperature  mar rain  \
# 0     -0.760930                 -1.377224                 -1.368383 -0.853291
# 1      0.410994                  1.013535                  0.788724 -0.817039
# 2     -0.453287                  1.152248                  1.300447 -0.742403
# 3      0.536521                  0.980897                  0.820215  1.266380
# 4     -0.659068                  0.768748                  1.237466 -0.251936
# ...         ...                       ...                       ...       ...
# 31739  1.696097                  0.817705                  0.820215  1.187479
# 31740 -0.705369                 -0.161445                 -0.155994 -0.411871
# 31741 -0.100372                 -1.042681                 -0.754316 -0.829834
# 31742  1.074638                  0.703471                  0.772979 -0.077074
# 31743 -0.246477                  0.393407                  0.828087 -0.038689
#
#        mar mean min temperature  mar mean max temperature  ...  oct rain  \
# 0                     -1.037363                 -0.939911  ... -0.822836
# 1                      1.001505                  0.749059  ... -0.789094
# 2                      1.281728                  1.370823  ...  0.462619
# 3                      1.078808                  0.786180  ...  0.428877
# 4                      0.499035                  0.981061  ... -0.582289
# ...                         ...                       ...  ...       ...
# 31739                  0.595664                  0.489218  ...  0.309148
# 31740                 -0.032424                 -0.086146  ... -0.041332
# 31741                 -1.008375                 -0.383108  ... -0.783652
# 31742                  0.325103                  0.479938  ... -0.014121
# 31743                 -0.138715                  0.173696  ...  0.300440
#
#        oct mean min temperature  oct mean max temperature  nov rain  \
# 0                     -0.773462                 -0.757178 -0.803809
# 1                      0.521304                  0.264323 -0.815056
# 2                      1.155993                  0.957484  1.188953
# 3                      1.054443                  1.139895  2.963932
# 4                      0.242040                  0.848037 -0.385625
# ...                         ...                       ...       ...
# 31739                  0.318203                  0.325126  1.015136
# 31740                 -0.291099                 -0.684213 -0.596251
# 31741                 -1.014644                 -0.307231 -0.682137
# 31742                  0.051634                  0.592662  0.493685
# 31743                 -0.519587                 -0.209945 -0.196471
#
#        nov mean min temperature  nov mean max temperature  dec rain  \
# 0                     -1.135123                 -1.024563 -0.721694
# 1                      0.914534                  0.622715 -0.422594
# 2                      1.217439                  1.121605 -0.699924
# 3                      1.096277                  1.065127  1.026530
# 4                      0.672210                  1.036888  0.258901
# ...                         ...                       ...       ...
# 31739                  0.662113                  0.726258  1.419336
# 31740                 -0.105246                 -0.591564 -0.357284
# 31741                 -1.175510                 -0.779824 -0.715069
# 31742                  0.520757                  0.660367 -0.326995
# 31743                  0.137078                  0.575650 -0.167980
#
#        dec mean min temperature  dec mean max temperature     yield
# 0                     -1.203860                 -1.091189 -0.067771
# 1                      0.970095                  0.766283 -0.831227
# 2                      1.110616                  1.023831 -0.794184
# 3                      1.036222                  0.906764 -0.681968
# 4                      0.763445                  0.891155 -0.734535
# ...                         ...                       ...       ...
# 31739                  0.879169                  0.922373 -0.034814
# 31740                 -0.492985                 -0.794618  0.746890
# 31741                 -1.253456                 -0.818031 -0.166914
# 31742                  0.920499                  1.218944  0.761054
# 31743                  0.639455                  1.140899 -0.206680
#
# [31744 rows x 38 columns]

# %%
#shuffle the data to avoid ordering bias...

train_set = df.sample(frac=0.6, random_state = 1453)
test_set = df.drop(train_set.index)

print('Training set size:', train_set.shape[0])
print('Test set size:', test_set.shape[0])

X_train_data = train_set.drop('yield', axis = 1)
# Out:
# Training set size: 19046
# Test set size: 12698
