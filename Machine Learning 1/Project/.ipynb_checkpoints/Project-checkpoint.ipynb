# %% [markdown]
# # <u>Lab 5 / Project</u>

# %%
#importing modules
import random
import time
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
#reading data into a dataframe
df = pd.read_csv('maize_major_yield.csv')
total_raw_rows = str(len(df))
print('The number of rows in the raw data set is: ' + total_raw_rows + '.')

#getting rid of outliers (anything outside of 3 standard deviations is considered an outlier)
df = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
total_cleaned_rows = str(len(df))
print('The number of rows in the cleaned data set is: ' + total_cleaned_rows + '.')

print('The number of rows removed from the raw data set is: ' + str(int(total_raw_rows) - int(total_cleaned_rows)) + '.')

#making a copy of the original
df_duplicate = df.copy()
# Out:
# The number of rows in the raw data set is: 31744.
# The number of rows in the cleaned data set is: 26498.
# The number of rows removed from the raw data set is: 5246.

# %% [markdown]
# ## <u>Exploration of the Target Variable:</u>
#
# #### Looking at the statistics of the yield values for the whole dataset.

# %%
#creating a dataframe for only the yield
yield_df = df_duplicate['yield']

#printing statistics
print('The minimum yield is: ' + str(round(yield_df.min(), 2)) + ' tonnes per hectare.')
print('The maximum yield is: ' + str(round(yield_df.max(), 2)) + ' tonnes per hectare.')
print('The mean yield is: ' + str(round(yield_df.mean(), 2)) + ' tonnes per hectare.')
print('The standard deviation of the yield is: ' + str(round(yield_df.std(), 2)) + ' tonnes per hectare.')
# Out:
# The minimum yield is: 0.0 tonnes per hectare.
# The maximum yield is: 14.62 tonnes per hectare.
# The mean yield is: 3.46 tonnes per hectare.
# The standard deviation of the yield is: 3.36 tonnes per hectare.

# %% [markdown]
# ## <u>Data Visualisations:</u>
#
# #### Visualisation of Average Yield Against Year:

# %%
#getting a dataframe of years
year_df = df_duplicate['year'].to_numpy()
individual_years = np.unique(year_df)
years_mean_dict = {}

#going through each year and getting the average yield
for year in individual_years:
    yields = df_duplicate.loc[df_duplicate['year'] == year, 'yield']
    years_mean_dict[year] = yields.mean()

#sorting all of the values recorded for each year
sorted_dict = dict(sorted(years_mean_dict.items(), key=lambda item: item[0]))

x_values = []
y_values = []

#finding the year and yield and storing them in 2 different lists
for key, value in sorted_dict.items():
    x_values.append(key)
    y_values.append(value)
    
x_bestfit = np.array(x_values)
y_bestfit = np.array(y_values)
m, b = np.polyfit(x_bestfit, y_bestfit, 1)

#plotting yield against year
plt.figure(figsize=[20,8])
plt.plot(x_values, y_values)
plt.plot(x_bestfit, m*x_bestfit + b)
plt.title('Average Yield Against Year:')
plt.xlabel('Year')
plt.ylabel('Average Yield (Tonnes/Hectare)')
plt.savefig('Average Yield Against Year.png', transparent=False, bbox_inches = 'tight', pad_inches = 0)
plt.show()

# %% [markdown]
# From the graph above, the conclusion that can be made is that there has been a steady increase in the average yield as time went on and that there is a positive correlation between the average yield and the year.

# %% [markdown]
# #### Visualisation of Average Yield Against Rainfall:
#
# Comparison of the yield against rainfall for 1983 and 2013 to allow for a comparison of the relationship over the course of 30 years.

# %%
#getting a dataframe for the year 1983 and getting the average yields for that year
df_1983 = df_duplicate.loc[df_duplicate['year'] == 1983]
df_1983_data = df_1983[df_1983.columns[df_1983.columns.to_series().str.contains('rain')]]
average = df_1983_data.mean(axis=1)
yields = df_1983['yield']

#plotting a graph for the 1983 data
plt.figure(figsize=[12,10])
plt.grid(True)
plt.title('Average Yield Against Rainfall For 1983')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (Tonnes/Hectare)')
plt.scatter(average, yields)
plt.show()


#getting a dataframe for the year 2013 and getting the average yields for that year
df_2013 = df_duplicate.loc[df_duplicate['year'] == 2013]
df_2013_data = df_2013[df_2013.columns[df_2013.columns.to_series().str.contains('rain')]]
average = df_2013_data.mean(axis=1)
yields = df_2013['yield']

#plotting a graph for the 1983 data
plt.figure(figsize=[12,10])
plt.grid(True)
plt.title('Average Yield Against Rainfall For 2013')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (Tonnes/Hectare)')
plt.scatter(average, yields)
plt.show()

# %% [markdown]
# The 2 scatter plots above have been plotted to show if there is any noticeable difference between the average yield against rainfall for the years 1983 and 2013.

# %% [markdown]
# ## <u>Data Preparation:</u>
#
# ### Normalising The Data Set:

# %%
#creating a dataframe of normalized data
normalize_df = df_duplicate.to_numpy()

#going through each data point and normalizing it (excluding the year)
for i in range(1, len(normalize_df[0])):
    normalize_df[:,i] = (normalize_df[:,i] - np.mean(normalize_df[:,i])) / np.std(normalize_df[:,i])


df = pd.DataFrame(normalize_df)
df.columns = df_duplicate.columns.values

df
# Out:
#          year  jan rain  jan mean min temperature  jan mean max temperature  \
# 0      1983.0 -0.771169                 -1.295743                 -1.195355
# 1      1983.0 -0.805892                  1.109767                  0.959782
# 2      1983.0 -0.805892                  0.933004                  1.078686
# 3      1983.0  2.499690                  1.063655                  0.878036
# 4      1983.0  0.721898                  0.933004                  1.160433
# ...       ...       ...                       ...                       ...
# 26493  2013.0  0.478841                  0.810039                  0.930056
# 26494  2013.0 -0.614918                 -0.365817                 -0.749464
# 26495  2013.0 -0.581353                 -0.942218                 -0.630560
# 26496  2013.0 -0.131118                  0.802354                  1.004371
# 26497  2013.0 -0.369546                  0.594850                  0.907762
#
# ...

# %% [markdown]
# ### PCA Reduction:

# %%
#use sklearn PCA
from sklearn.decomposition import PCA

#create a new dataframe and fit it
PCA_df = df.copy().to_numpy()
PCA_df2 = PCA_df[:,:-1]
pca = PCA().fit(PCA_df2.data)

print('The number of features we have before PCA reduction is: ' + str(len(np.cumsum(pca.explained_variance_ratio_))) + '.')
# Out:
# The number of features we have before PCA reduction is: 37.

# %%
#plotting the variance against the number of components chosen
plt.figure(figsize=[16,10])
plt.title("Cumulative Variance Against Components")
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Variance')
plt.xticks(np.arange(PCA_df2.shape[1]), np.arange(1, PCA_df2.shape[1]+1))

#checking for the minimum number of components that contains 95% of the original data
plt.axhline(y = 0.95, color = 'g', linestyle = '--')
plt.axvline(x=5, color='r', linestyle = '--')
plt.axvline(x=4, color='r', linestyle = '--')
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.savefig('Cumulative Variance Against Components.png', bbox_inches = 'tight', pad_inches = 0)
plt.show()

# %%
#going through the number of components and manually checking the variance
for i in range(20):
    pca = PCA(n_components = i)
    x_reduced = pca.fit_transform(PCA_df2.data)
    
    #once i has been found stop
    if np.sum(pca.explained_variance_ratio_) > 0.95:
        break

#print the component and it's associated variance
print('The number of components is: ' + str(i) + '.')
print('The variance with this number of components is: ' + str(np.sum(pca.explained_variance_ratio_)) + '.')

#creating a new dataframe with the reduced data
X_reduced_df = pd.DataFrame(x_reduced)
Y_df = pd.DataFrame(PCA_df[:,-1])
Y_df = Y_df.rename(columns = {0: 'yield'})

final_df = pd.concat([X_reduced_df, Y_df], axis = 1)
# Out:
# The number of components is: 6.
# The variance with this number of components is: 0.9526520436266073.

# %% [markdown]
# ### Doing Splits:
#
# Creating the training, validation and testing sets with a 60/20/20 split respectively.

# %%
#setting percentages for the train, validation and test splits
split_ratios = np.array([0.6, 0.2, 0.2])

# shuffle the input
df = final_df.sample(frac = 1, random_state = 10)

# split into 3 different splits
train_split, val_split, test_split = np.array_split(df, (split_ratios[:-1].cumsum() * len(df)).astype(int))

#printing out the values for each
print('The training set size is: ', (len(train_split)))
print('The validation set size is: ', (len(val_split)))
print('The test set size is: ', (len(test_split)))
# Out:
# The training set size is:  15898
# The validation set size is:  5300
# The test set size is:  5300

# %%
#setting training, validation and test variables for X and Y
X_train = train_split.drop('yield', axis = 1).to_numpy()
X_val = val_split.drop('yield', axis = 1).to_numpy()
X_test = test_split.drop('yield', axis = 1).to_numpy()

Y_train = train_split['yield'].to_numpy()
Y_val = val_split['yield'].to_numpy()
Y_test = test_split['yield'].to_numpy()

# %% [markdown]
# ## <u> First Model: Linear Regression:</u>
#
# Implementing the linear regressions algorithm.

# %%
#doing a linear regression
LR_train_start_time = time.time()
beta_hat = np.linalg.inv(X_train.T.dot(X_train)).dot(X_train.T).dot(Y_train)
LR_train_end_time = time.time()

LR_train_time = LR_train_end_time - LR_train_start_time

#creating a function to calculate the mean squared error of the 2 input variables
def lin_reg(X_var, Y_var):
    
    y_hat = np.round(X_var.dot(beta_hat), 3)
    mean_squared_error = np.square(np.subtract(Y_var, y_hat)).mean()
    return mean_squared_error, y_hat

#running and printing the results
start_time = time.time()
LR_MSE_train, LR_train_predictions = lin_reg(X_train, Y_train)
LR_MSE_test, LR_test_predictions = lin_reg(X_test, Y_test)
end_time = time.time()

LR_r2_train = r2_score(Y_train, LR_train_predictions, sample_weight = None, multioutput = 'uniform_average')
LR_r2_train = round(LR_r2_train, 9)

LR_r2_test = r2_score(Y_test, LR_test_predictions, sample_weight = None, multioutput = 'uniform_average')
LR_r2_test = round(LR_r2_test, 9)

print('The MSE value running a LR on the training data is: ' + str(round(LR_MSE_train, 5)))
print('The MSE value running a LR on the test data is: ' + str(round(LR_MSE_test, 5)))
print('The R^2 score value for a LR on train data is: ' + str(LR_r2_train))
print('The R^2 score value for a LR on test data is: ' + str(LR_r2_test))

LR_running_time = end_time - start_time
LR_running_time = round(LR_running_time, 8)
print('The running time for the LR is ' + str(LR_running_time) + ' seconds.')
# Out:
# The MSE value running a LR on the training data is: 0.62706
# The MSE value running a LR on the test data is: 0.63131
# The R^2 score value for a LR on train data is: 0.369641633
# The R^2 score value for a LR on test data is: 0.372529484
# The running time for the LR is 0.00099993 seconds.

# %% [markdown]
# ## <u> Second Model: Regression Forest:</u>
#
# Implementing the regression forest algorithm.

# %%
def find_split(x, y, subspace):
    
    start_variance = np.var(y)
    best = {'variance' : start_variance}
    
    indices = list(range(x.shape[1]))
    random.seed(1234)
    
    if subspace and subspace <= len(indices):
        indices = random.sample(indices, subspace)
    
    for i in indices:
        
        length = len(np.unique(x[:,i]))
        maximum = max(np.unique(x[:,i]))
        minimum = min(np.unique(x[:,i]))
        bins = 10
        
        split_number = (length % bins > 0) + int(length / bins)
        splits = np.linspace(minimum, maximum, split_number)
        
        for split in splits:
                       
            lhs = y[x[:,i] <= split]
            rhs = y[x[:,i] > split]
            
            len_lhs = len(lhs)
            len_rhs = len(rhs)
            
            total = len_lhs + len_rhs
            
            fraction_lhs = len_lhs / total
            fraction_rhs = len_rhs / total
                  
            variance_lhs = np.var(lhs)
            variance_rhs = np.var(rhs)
            
            variance = fraction_rhs*variance_rhs + fraction_lhs*variance_lhs        
                
            left_array = np.where(x[:,i] <= split)
            right_array = np.where(x[:,i] > split)
            
            left_indices = np.array(left_array)[0].tolist()
            right_indices = np.array(right_array)[0].tolist()
            
            if variance < best['variance']:
                best = {'feature' : i,
                        'split' : split,
                        'variance' : variance, 
                        'left_indices' : left_indices,
                        'right_indices' : right_indices}
    
    return best

# %%
def build_tree(x, y, subspace, max_depth = 3):
    

    if max_depth==1 or (y==y[0]).all():
        # Generate a leaf node...
        average = np.mean(y)
        average = average.round(3)
        
        return {'leaf': True, 'predict': average}
    
    else:
        move = find_split(x, y, subspace)
        
        if (len(move) == 1):
            return {'leaf' : True, 'predict' : np.mean(y)} 
        
        left = build_tree(x[move['left_indices'],:], y[move['left_indices']], max_depth - 1, subspace)
        right = build_tree(x[move['right_indices'],:], y[move['right_indices']], max_depth - 1, subspace)
        
        return {'leaf' : False,
                'feature' : move['feature'],
                'split' : move['split'],
                'variance' : move['variance'],
                'left' : left,
                'right' : right}

# %%
def predict(tree, samples):
    
    """Predicts every entry of a data matrix."""
    ret = np.empty(samples.shape[0], dtype=float)
    ret.fill(-1)
    indices = np.arange(samples.shape[0])
    
    def tranverse(node, indices):
        nonlocal samples
        nonlocal ret
        
        if node['leaf']:
            ret[indices] = node['predict']
        
        else:
            going_left = samples[indices, node['feature']] <= node['split']
            left_indices = indices[going_left]
            right_indices = indices[np.logical_not(going_left)]
            
            if left_indices.shape[0] > 0:
                tranverse(node['left'], left_indices)
                
            if right_indices.shape[0] > 0:
                tranverse(node['right'], right_indices)
    
    tranverse(tree, indices)
    return ret

# %%
def bootstrap(x, y, n):
    
    np.random.seed(1234)
    indices = np.random.randint(0, len(x), n)
    y = y[indices]
    x = x[indices]
    
    return x, y

# %%
def random_forest(x, y, tree_no, boostrap, features, depth):
    
    forest_list = []
    
    for i in range(tree_no):
        
        x, y = bootstrap(x, y, boostrap)
        tree = build_tree(x, y, features, depth)
        forest_list.append(tree)
        
    return forest_list

# %%
def predicting_forest(forest, input_data):
    
    predictions = []
    
    for tree in forest:
        predictions.append(predict(tree,input_data))
        
    return np.mean(predictions, axis = 0)

# %%
def optimizing_RF_parameters():
    
    best_MSE = 1000
    best_depth = None
    best_bootstrap = None
    best_tree_number = None
    best_feature_number = None
    
    MSE_list = []
    depth_list = []
    bootstrap_list = []
    tree_number_list = []
    feature_number_list = []
    
    for h in range(5, 25, 5):
        for i in range(5,35, 5):
            for j in range(2000, 5000, 500):
                for k in range(3, 10):
                    forest = random_forest(X_val, Y_val, tree_no = i, boostrap = j, features = k, depth = h)
                    val_predicting = predicting_forest(forest, X_val)
                    val_MSE = np.square(np.subtract(Y_val, val_predicting)).mean()
                    if val_MSE < best_MSE:
                        best_MSE = val_MSE
                        best_depth = h
                        best_tree_number = i
                        best_bootstrap = j
                        best_feature_number = k
                        
                        MSE_list.append(best_MSE)
                        depth_list.append(best_depth)
                        tree_number_list.append(best_tree_number)
                        bootstrap_list.append(best_bootstrap)
                        feature_number_list.append(best_feature_number)
                        
    print('The best MSE is: ' + str(best_MSE))
    print('The best depth is: ' + str(best_depth))
    print('The best bootstrap value is: ' + str(best_bootstrap))
    print('The best tree number is: ' + str(best_tree_number))
    print('The best feature number is: ' + str(best_feature_number))
    
    return MSE_list, depth_list, tree_number_list, bootstrap_list, feature_number_list

RF_MSE_list, RF_depth_list, RF_tree_number_list, RF_bootstrap_list, RF_feature_number_list = optimizing_RF_parameters()
# Out:
# D:\Documents\Programming\Anaconda\envs\ML\lib\site-packages\numpy\core\fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# D:\Documents\Programming\Anaconda\envs\ML\lib\site-packages\numpy\core\_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# D:\Documents\Programming\Anaconda\envs\ML\lib\site-packages\numpy\core\_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# The best MSE is: 0.2922562252002431
# The best depth is: 15
# The best bootstrap value is: 4500
# The best tree number is: 5
# The best feature number is: 9

# %%
plt.figure(figsize=[16,10])
plt.plot(RF_depth_list, RF_MSE_list, 'x')
plt.xticks(np.arange(4, 16, 1))
plt.title("Mean Squared Error Against Depth")
plt.xlabel('Depth')
plt.ylabel('Mean Squared Error')
plt.savefig("Mean Squared Error Against Depth.png", bbox_inches = 'tight', pad_inches = 0)

# %%
plt.figure(figsize=[16,10])
plt.plot(RF_feature_number_list, RF_MSE_list, 'x')
plt.xticks(np.arange(2, 10, 1))
plt.title('Mean Squared Error Against Number of Features')
plt.xlabel('Number of Features')
plt.ylabel('Mean Squared Error')
plt.savefig('Mean Squared Error Against Number of Features.png', bbox_inches = 'tight', pad_inches = 0)

# %%
def evaluating_tree(X_train, Y_train, X_test, Y_test, tree_no = 5, bootstrap_no = 4500, features = 9, depth = 15):
    
    RF_training_start_time = time.time()
    creating_forest = random_forest(X_train, Y_train, tree_no, bootstrap_no, features, depth)
    
    train_predict = predicting_forest(creating_forest, X_train)
    RF_training_end_time = time.time()
    
    RF_training_time = RF_training_end_time - RF_training_start_time
    
    MSE_train = np.square(np.subtract(Y_train, train_predict)).mean()
    
    RF_test_start_time = time.time()
    test_predict = predicting_forest(creating_forest, X_test)
    RF_test_end_time = time.time()
    
    RF_testing_time = RF_test_end_time - RF_test_start_time
    
    MSE_test = np.square(np.subtract(Y_test, test_predict)).mean()
    
    print('The running time for the RF on train data is: ' + str(RF_training_time) + ' seconds.')
    print('The running time for the RF on test data is: ' + str(RF_testing_time) + ' seconds.')
    
    return MSE_train, MSE_test, train_predict, test_predict

# %%
MSE_train, MSE_test, train_predict, test_predict = evaluating_tree(X_train, Y_train, X_test, Y_test)

RF_MSE_train = round(MSE_train, 3)
RF_MSE_test = round(MSE_test, 3)

RF_r2_test = r2_score(Y_test, test_predict, sample_weight = None, multioutput = 'uniform_average')
RF_r2_test = round(RF_r2_test, 3)

RF_r2_train = r2_score(Y_train, train_predict, sample_weight = None, multioutput = 'uniform_average')
RF_r2_train = round(RF_r2_train, 3)

print('The MSE value running a RF on the training data is: ' + str(RF_MSE_train))
print('The MSE value running a RF on the test data is: ' + str(RF_MSE_test))
print('The R^2 score value for a RF on train is: ' + str(RF_r2_train))
print('The R^2 score value for a RF on test is: ' + str(RF_r2_test))
# Out:
# The running time for the RF on train data is: 8.234850406646729 seconds.
# The running time for the RF on test data is: 0.04601025581359863 seconds.
# The MSE value running a RF on the training data is: 0.381
# The MSE value running a RF on the test data is: 0.436
# The R^2 score value for a RF on train is: 0.617
# The R^2 score value for a RF on test is: 0.566

# %% [markdown]
# ## <u> Third Model: Gaussian Process:</u>
#
# Implementing the Gaussian Process algorithm.

# %%
def kernel(X, Y, l=1.0, sigma_f=1.0):
    
    sqdist = np.sum(X**2, 1).reshape(-1, 1) + np.sum(Y**2, 1) - 2 * np.dot(X, Y.T)
    return sigma_f**2 * np.exp(-0.5 / l**2 * sqdist)

# %%
def posterior_function(X, Y, X_test, l=1.0, sigma_f=1.0, sigma_y=1e-8):
    
    length = len(X)
    GP_train_start_time = time.time()
    kern = kernel(X, X, 1)
    L = np.linalg.cholesky(kern + sigma_y*np.eye(length))
    GP_train_end_time = time.time()
    
    GP_train_time = GP_train_end_time - GP_train_start_time
    
    GP_test_start_time = time.time()
    Lk = np.linalg.solve(L, kernel(X, X_test, l))
    predictions = np.dot(Lk.T, np.linalg.solve(L, Y))
    GP_test_end_time = time.time()
    
    GP_test_time = GP_test_end_time - GP_test_start_time
    
    return predictions, GP_train_time, GP_test_time

# %%
def optimizing_Gaussian_parameters():
    
    best_MSE = 1000
    best_l = None
    best_sigma_f = None
    best_sigma_y = None
        
    MSE_list = []
    l_values_list = []
    sigma_f_values_list = []
    sigma_y_values_list = []
  
    l_values = np.linspace(0.1,1.0,10)
    sigma_f_values = np.linspace(0.1,1.0,10)
    sigma_y_values = np.linspace(0.1,1.0,10)
    
    X_opt_train = X_val[:2500]
    Y_opt_train = Y_val[:2500]
    
    X_opt_val = X_train[:2500]
    Y_opt_val = Y_train[:2500]
    
    for l_value in l_values:
        for sigma_f_value in sigma_f_values:
            for sigma_y_value in sigma_y_values:
                predictions, GP_opt_train_time, GP_opt_test_time = posterior_function(X_opt_train, Y_opt_train, X_opt_val, l=l_value, sigma_f=sigma_f_value, sigma_y=sigma_y_value)
                score = np.square(np.subtract(Y_opt_val, predictions)).mean()
                if score < best_MSE:
                    best_MSE = score
                    best_l = l_value
                    best_sigma_f = sigma_f_value
                    best_sigma_y = sigma_y_value
                    
                    MSE_list.append(best_MSE)
                    l_values_list.append(best_l)
                    sigma_f_values_list.append(best_sigma_f)
                    sigma_y_values_list.append(best_sigma_y)
    
    print('The Mean Squared Error for the Validation Set is: ' + str(best_MSE))
    print('The best l value to use is: ' + str(best_l))
    print('The best sigma_f value to use is: ' + str(best_sigma_f))
    print('The best sigma_y value to use is: ' + str(best_sigma_y))
    
    return MSE_list, l_values_list, sigma_f_values_list, sigma_y_values_list
    
G_MSE_list, G_l_values_list, G_sigma_f_list, G_sigma_y_list = optimizing_Gaussian_parameters()
# Out:
# The Mean Squared Error for the Validation Set is: 0.5339579806990722
# The best l value to use is: 1.0
# The best sigma_f value to use is: 0.1
# The best sigma_y value to use is: 0.2

# %%
plt.figure(figsize=[16,10])
plt.plot(G_l_values_list, G_MSE_list, 'x')
plt.xticks(np.arange(0, 1.1, 0.1))
plt.title('Mean Squared Error Against \'l\' Value')
plt.xlabel('\'l\' Value')
plt.ylabel('Mean Squared Error')
plt.savefig('Mean Squared Error Against L Value', bbox_inches = 'tight', pad_inches = 0)

# %%
start_time = time.time()
GP_predicting_test, GP_train_time, GP_test_time = posterior_function(X_train[0:10000], Y_train[0:10000], X_test, l=1, sigma_f=0.1, sigma_y=0.2)
end_time = time.time()

Gaussian_running_time = end_time - start_time
Gaussian_running_time = round(Gaussian_running_time, 3)

Gaussian_MSE = np.square(np.subtract(Y_test, GP_predicting_test)).mean()
Gaussian_MSE = round(Gaussian_MSE, 3)

GP_r2 = r2_score(Y_test, GP_predicting_test, sample_weight = None, multioutput = 'uniform_average')
GP_r2 = round(GP_r2, 3)

print('The MSE value running a GP is: ' + str(Gaussian_MSE))
print('The R^2 score for a GP is: ' + str(GP_r2))
print('The running time for the GP on train data is: ' + str(GP_train_time) + ' seconds.')
print('The running time for the GP on test data is: ' + str(GP_test_time) + ' seconds.')
# Out:
# The MSE value running a GP is: 0.354
# The R^2 score for a GP is: 0.648
# The running time for the GP on train data is: 4.663048267364502 seconds.
# The running time for the GP on test data is: 11.384536027908325 seconds.

# %% [markdown]
# ## <u> Fourth Model: Neural Network:</u>
#
# Implementing a Neural Network.

# %%
#import modules needed to implement a neural network
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

# %%
#function to plot the error of the training and validation set of the NN
def plot_NN_result(data):
    
    val_df = pd.DataFrame(data.history)
    val_df['epoch'] = data.epoch
    plt.figure(figsize=[16,10])
    plt.plot(val_df['epoch'], val_df['loss'], label = 'Error For Training Data')
    plt.plot(val_df['epoch'], val_df['val_mse'], label = 'Error For Validation Data')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Squared Error')
    plt.title('')
    plt.ylim([0.25, 0.5])
    plt.legend()

# %%
# creating a neural network with 2 layers
model = Sequential()
#first layer
model.add(Dense(64, input_dim = X_train.shape[1], activation = tf.nn.relu))
#second layer
model.add(Dense(64, activation = tf.nn.relu))
model.add(Dense(1))
model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mse'])

#conditions to stop the NN early
monitor = EarlyStopping(monitor = 'val_loss', min_delta = 1e-6, patience = 100, verbose = 1, mode = 'auto', restore_best_weights = True)
#training the model
unoptimized_values = model.fit(X_train, Y_train, validation_data = (X_val, Y_val), callbacks = [monitor], verbose = 0, epochs = 160)

# %%
#plotting the error for training against validation data
plot_NN_result(unoptimized_values)
plt.title('Mean Squared Error Against Epoch Number')
plt.savefig('High Patience NN Graph.png', bbox_inches = 'tight', pad_inches = 0)

# %%
#recreating the neural network which will be optimized
optimized_model = Sequential()
optimized_model.add(Dense(64, input_dim = X_train.shape[1], activation = tf.nn.relu))
optimized_model.add(Dense(64, activation = tf.nn.relu))
optimized_model.add(Dense(1))
optimized_model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mse'])

monitor = EarlyStopping(monitor = 'val_loss', min_delta = 1e-6, patience = 5, verbose = 1, mode = 'auto', restore_best_weights = True)
start_train_time = time.time()
optimized_values = optimized_model.fit(X_train, Y_train, validation_data = (X_val, Y_val), callbacks = [monitor], verbose = 0, epochs = 160)
end_train_time = time.time()
train_running_time = end_train_time - start_train_time
# Out:
# Restoring model weights from the end of the best epoch.
# Epoch 00062: early stopping

# %%
plot_NN_result(optimized_values)
plt.title('Mean Squared Error Against Epoch Number')
plt.savefig('Low Patience NN Graph.png', bbox_inches = 'tight', pad_inches = 0)

# %%
start_test_time = time.time()
loss, NN_MSE = optimized_model.evaluate(X_test, Y_test)
end_test_time = time.time()
test_running_time = end_test_time - start_test_time

loss_train, NN_MSE_train = optimized_model.evaluate(X_train, Y_train)

NN_train_predictions = optimized_model.predict(X_train)
NN_test_predictions = optimized_model.predict(X_test)

NN_train_r2 = r2_score(Y_train, NN_train_predictions, sample_weight = None, multioutput = 'uniform_average')
NN_test_r2 = r2_score(Y_test, NN_test_predictions, sample_weight = None, multioutput = 'uniform_average')

NN_train_r2 = round(NN_train_r2, 3)
NN_test_r2 = round(NN_test_r2, 3)
loss_val = round(loss, 5)
loss_train = round(loss_train, 5)

print('The MSE for value running a NN on the train set is: ' + str(loss_train))
print('The MSE for value running a NN on the test set is: ' + str(loss_val))
print('The R^2 value running the NN on the train set was: ' + str(NN_train_r2))
print('The R^2 value running the NN on the test set was: ' + str(NN_test_r2))
print('The training running time for the NN was ' + str(train_running_time) + ' seconds.')
print('The test running time for the NN was ' + str(test_running_time) + ' seconds.')
# Out:
# ...
# 497/497 [==============================] - 0s 298us/step - loss: 0.2923 - mse: 0.2923
# The MSE for value running a NN on the train set is: 0.29232
# The MSE for value running a NN on the test set is: 0.32583
# The R^2 value running the NN on the train set was: 0.706
# The R^2 value running the NN on the test set was: 0.676
# The training running time for the NN was 13.232174396514893 seconds.
# The test running time for the NN was 0.07901811599731445 seconds.

# %% [markdown]
# ## Using A Toy Problem for Validation:

# %%
np.random.seed(1234)
X_toy_data = np.random.normal(size = 100)
Y_toy_data = X_toy_data

# %%
plt.figure(figsize=[16,10])
plt.plot(X_toy_data, Y_toy_data, 'x')
plt.title('Data Set For Toy Problem')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.savefig('Toy Data Set Plot.png', bbox_inches = 'tight', pad_inches = 0)

# %%
toy_data = np.column_stack((X_toy_data, Y_toy_data))
np.random.shuffle(toy_data)

toy_train, toy_test = toy_data[40:,:], toy_data[:40,:]

X_toy_train = toy_train[:,0].reshape(toy_train[:,0].shape[0],1)
Y_toy_train = toy_train[:,1].reshape(toy_train[:,0].shape[0],1)

X_toy_test = toy_test[:,0].reshape(toy_test[:,0].shape[0],1)
Y_toy_test =toy_test[:,1].reshape(toy_test[:,0].shape[0],1)

# %% [markdown]
# ## Toy Problem - Linear Regression

# %%
beta_toy_hat = np.linalg.inv(X_toy_train.T.dot(X_toy_train)).dot(X_toy_train.T).dot(Y_toy_train)

def lin_reg_toy(X_var, Y_var):
    
    y_hat = np.round(X_var.dot(beta_toy_hat), 3)
    mean_squared_error = np.square(np.subtract(Y_var, y_hat)).mean()
    return mean_squared_error, y_hat

# %%
test_error, test_predictions = lin_reg_toy(X_toy_test, Y_toy_test)

LRtoy_r2 = r2_score(Y_toy_test, test_predictions, sample_weight = None, multioutput = 'uniform_average')
LRtoy_r2 = round(LRtoy_r2, 3)

print('The MSE value for running the LR on the toy test data is: ' + str(test_error))
print('The R^2 score for a LR on a toy problem is: ' + str(LRtoy_r2))
# Out:
# The MSE value for running the LR on the toy test data is: 7.564887974569667e-08
# The R^2 score for a LR on a toy problem is: 1.0

# %%
plt.figure(figsize=[16,10])
plt.plot(Y_toy_test - test_predictions, 'x')
plt.title('Residuals For Linear Regression Predictions')
plt.xlabel('Data Point In Test Set')
plt.ylabel('Residual Value')
plt.axhline(y=0, color='r', linestyle='--')
plt.savefig('LR Residuals.png', bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Toy Problem - Random Forest

# %%
MSE_train, MSE_test, train_predictions, test_predictions = evaluating_tree(X_toy_train, Y_toy_train, X_toy_test, Y_toy_test, bootstrap_no = 100, features = 1, depth = 2)

MSE_train = round(MSE_train, 3)
MSE_test = round(MSE_test, 3)

RFtoy_r2 = r2_score(Y_toy_test, test_predictions, sample_weight = None, multioutput = 'uniform_average')
RFtoy_r2 = round(RFtoy_r2, 3)

print('The MSE value running the RF on the training toy data is: ' + str(MSE_train))
print('The MSE value running the RF on the test toy data is: ' + str(MSE_test))
print('The R^2 score running a RF on the test toy data is: ' + str(RFtoy_r2))
# Out:
# The running time for the RF on train data is: 0.004001617431640625 seconds.
# The running time for the RF on test data is: 0.0 seconds.
# The MSE value running the RF on the training toy data is: 1.483
# The MSE value running the RF on the test toy data is: 1.011
# The R^2 score running a RF on the test toy data is: 0.702
# D:\Documents\Programming\Anaconda\envs\ML\lib\site-packages\numpy\core\fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# D:\Documents\Programming\Anaconda\envs\ML\lib\site-packages\numpy\core\_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# D:\Documents\Programming\Anaconda\envs\ML\lib\site-packages\numpy\core\_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Toy Problem - Gaussian Process

# %%
def kernel(X, Y, l=1.0, sigma_f=1.0):

    sqdist = np.sum(X**2, 1).reshape(-1, 1) + np.sum(Y**2, 1) - 2 * np.dot(X, Y.T)
    return sigma_f**2 * np.exp(-0.5 / l**2 * sqdist)

# %%
def toy_posterior_function(X, Y, X_test, l=1.0, sigma_f=0.1, sigma_y=0.2):
    
    length = len(X)
    kern = kernel(X, X, 1)

    L = np.linalg.cholesky(kern + sigma_y*np.eye(length))
    Lk = np.linalg.solve(L, kernel(X, X_test, l))
    
    return np.dot(Lk.T, np.linalg.solve(L, Y))

# %%
Y_toy_predictions = toy_posterior_function(X_toy_train, Y_toy_train, X_toy_test)
toy_mean_squared_error = np.square(np.subtract(Y_toy_test, Y_toy_predictions)).mean()

GPtoy_r2 = r2_score(Y_toy_test, Y_toy_predictions, sample_weight = None, multioutput = 'uniform_average')
GPtoy_r2 = round(GPtoy_r2, 3)

print('The MSE for the Gaussian Process on the toy test data is: ' + str(toy_mean_squared_error))
print('The R^2 score running a GP on a toy problem is: ' + str(GPtoy_r2))
# Out:
# The MSE for the Gaussian Process on the toy test data is: 0.0001985521024650008
# The R^2 score running a GP on a toy problem is: 1.0

# %%
plt.figure(figsize=[16,10])
plt.plot(X_toy_test, Y_toy_test)
plt.plot(X_toy_test, Y_toy_predictions, 'x')
plt.title('Predicted Values For Gaussian Process')
plt.xlabel('X Value')
plt.ylabel('Y Value')

plt.savefig('GP Prediction.png', bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Toy Problem - Neural Network

# %%
#recreating the neural network which will be optimized
toy_model = Sequential()
toy_model.add(Dense(64, input_dim = X_toy_train.shape[1], activation = tf.nn.relu))
toy_model.add(Dense(64, activation = tf.nn.relu))
toy_model.add(Dense(1))
toy_model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mse'])

toy_values = toy_model.fit(X_toy_train, Y_toy_train, verbose = 0, epochs = 100)
toy_loss, toy_NN_MSE = toy_model.evaluate(X_toy_test, Y_toy_test)

NN_toy_predictions = toy_model.predict(X_toy_test)
NNtoy_r2 = r2_score(Y_toy_test, NN_toy_predictions, sample_weight = None, multioutput = 'uniform_average')
NNtoy_r2 = round(NNtoy_r2, 3)

print('The MSE for the NN on the toy test data is: ' + str(toy_loss))
print('The R^2 score running a NN on a toy problem is: ' + str(NNtoy_r2))
# Out:
# ...
# 2/2 [==============================] - 0s 1000us/step - loss: 3.1115e-05 - mse: 3.1115e-05
# The MSE for the NN on the toy test data is: 3.111450496362522e-05
# The R^2 score running a NN on a toy problem is: 1.0

# %%
toy_graph = pd.DataFrame(toy_values.history)
toy_graph['epoch'] = toy_values.epoch

plt.figure(figsize=[16,10])
plt.plot(toy_graph['epoch'], toy_graph['loss'])
plt.title('Mean Squared Error Against Epoch Number')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.savefig('NN Toy Problem Graph.png', bbox_inches = 'tight', pad_inches = 0)
